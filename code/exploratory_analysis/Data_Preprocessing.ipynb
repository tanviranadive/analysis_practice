# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
sns.set(style="white")

# %%
accidents = pd.read_csv('/home/tanvi/Downloads/1-6m-accidents-traffic-flow-over-16-years/accidents_2012_to_2014.csv',#nrows=12345,
                 parse_dates=[['Date', 'Time']],keep_date_col=True)

# %%
accidents.head()
# Out:
#           Date_Time Accident_Index  Location_Easting_OSGR  \
# 0  19/01/2012 20:35  201201BS70001                 527200
# 1  04/01/2012 17:00  201201BS70002                 524930
# 2  10/01/2012 10:07  201201BS70003                 525860
# 3  18/01/2012 12:20  201201BS70004                 524980
# 4  17/01/2012 20:24  201201BS70005                 526170
#
#    Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 0                  178760  -0.169101  51.493429             1
# 1                  181430  -0.200838  51.517931             1
# 2                  178080  -0.188636  51.487618             1
# 3                  181030  -0.200259  51.514325             1
# 4                  179200  -0.183773  51.497614             1
#
#    Accident_Severity  Number_of_Vehicles  Number_of_Casualties  ...   \
# 0                  3                   2                     1  ...
# 1                  3                   2                     1  ...
# ...

# %%
missing_values_count = accidents.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[:]
# Out:
# Date_Time                                           0
# Accident_Index                                      0
# Location_Easting_OSGR                               0
# Location_Northing_OSGR                              0
# Longitude                                           0
# Latitude                                            0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                               13
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     0
# ...

# %%
total_cells = np.product(accidents.shape)
total_missing = missing_values_count.sum()
print(total_missing)
print(total_cells)

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 672800
# 15799698
# 0

# %%
accidents.dropna()
total_cells = np.product(accidents.shape)
print(total_cells)
# Out:
# 15799698

# %%
accidents.head()
# Out:
#           Date_Time Accident_Index  Location_Easting_OSGR  \
# 0  19/01/2012 20:35  201201BS70001                 527200
# 1  04/01/2012 17:00  201201BS70002                 524930
# 2  10/01/2012 10:07  201201BS70003                 525860
# 3  18/01/2012 12:20  201201BS70004                 524980
# 4  17/01/2012 20:24  201201BS70005                 526170
#
#    Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 0                  178760  -0.169101  51.493429             1
# 1                  181430  -0.200838  51.517931             1
# 2                  178080  -0.188636  51.487618             1
# 3                  181030  -0.200259  51.514325             1
# 4                  179200  -0.183773  51.497614             1
#
#    Accident_Severity  Number_of_Vehicles  Number_of_Casualties  ...   \
# 0                  3                   2                     1  ...
# 1                  3                   2                     1  ...
# ...

# %%
accidents['Latitude'] = accidents['Latitude'].apply(pd.to_numeric, errors='coerce')
#df = accidents[accidents.Latitude <= 51.51279 and accidents.Longituded <= -0.09184]
#df.head()

# %%
accidents['Longitude'] = accidents['Longitude'].apply(pd.to_numeric, errors='coerce')

# %%
df = accidents[(accidents['Latitude'] <= 51.51279) & (accidents['Longitude'] <= -0.09184)]
df.head()
df.count()
# Out:
# Date_Time                                      98650
# Accident_Index                                 98650
# Location_Easting_OSGR                          98650
# Location_Northing_OSGR                         98650
# Longitude                                      98650
# Latitude                                       98650
# Police_Force                                   98650
# Accident_Severity                              98650
# Number_of_Vehicles                             98650
# Number_of_Casualties                           98650
# Date                                           98650
# Day_of_Week                                    98650
# Time                                           98650
# Local_Authority_(District)                     98650
# Local_Authority_(Highway)                      98650
# 1st_Road_Class                                 98650
# 1st_Road_Number                                98650
# Road_Type                                      98650
# ...
